# %%
import os

# %%
os.listdir(path='.')
# Out:
# ['.anaconda',
#  '.aws',
#  '.bashrc',
#  '.bash_history',
#  '.bash_logout',
#  '.cache',
#  '.cdk',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.docker',
#  '.dvdcss',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.local',
#  '.MakeMKV',
#  '.matplotlib',
#  '.npm',
#  '.nvm',
#  '.profile',
#  '.pyenv',
#  '.pylint.d',
#  '.python_history',
#  '.QtWebEngineProcess',
#  '.ssh',
#  '.sudo_as_admin_successful',
#  '.viminfo',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-server',
#  '.wget-hsts',
#  '3D Objects',
#  'Anaconda Work Space',
#  'AnacondaProjects',
#  'AppData',
#  'Application Data',
#  'aws',
#  'awscliv2.zip',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'dev',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'Favorites',
#  'getting-started',
#  'Google ドライブ',
#  'gsview32.ini',
#  'gsview64.ini',
#  'intro-aws',
#  'Links',
#  'Local Settings',
#  'mercurial.ini',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
# ...

# %%
path = os.getcwd()
print(path)
# Out:
# /mnt/c/Users/veyro/Documents/mirai_emu

# %%
home_directory = os.path.expanduser('~')
print(home_directory)
# Out:
# /mnt/c/Users/veyro

# %%
os.chdir(home_directory)
print(os.getcwd())
# Out:
# /mnt/c/Users/veyro

# %%
os.listdir(path=home_directory)
# Out:
# ['.anaconda',
#  '.aws',
#  '.bashrc',
#  '.bash_history',
#  '.bash_logout',
#  '.cache',
#  '.cdk',
#  '.conda',
#  '.condarc',
#  '.config',
#  '.docker',
#  '.dvdcss',
#  '.gitconfig',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.keras',
#  '.local',
#  '.MakeMKV',
#  '.matplotlib',
#  '.npm',
#  '.nvm',
#  '.profile',
#  '.pyenv',
#  '.pylint.d',
#  '.python_history',
#  '.QtWebEngineProcess',
#  '.ssh',
#  '.sudo_as_admin_successful',
#  '.viminfo',
#  '.VirtualBox',
#  '.vscode',
#  '.vscode-server',
#  '.wget-hsts',
#  '3D Objects',
#  'Anaconda Work Space',
#  'AnacondaProjects',
#  'AppData',
#  'Application Data',
#  'aws',
#  'awscliv2.zip',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'dev',
#  'Documents',
#  'Downloads',
#  'Dropbox',
#  'Favorites',
#  'getting-started',
#  'Google ドライブ',
#  'gsview32.ini',
#  'gsview64.ini',
#  'intro-aws',
#  'Links',
#  'Local Settings',
#  'mercurial.ini',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
# ...

# %%
files = os.listdir(home_directory)
files_file = [f for f in files if os.path.isfile(os.path.join(home_directory, f))]
print(files_file)
# Out:
# ['.bashrc', '.bash_history', '.bash_logout', '.condarc', '.gitconfig', '.profile', '.python_history', '.sudo_as_admin_successful', '.viminfo', '.wget-hsts', 'awscliv2.zip', 'gsview32.ini', 'gsview64.ini', 'mercurial.ini', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini']

# %%
files_dir = [f for f in files if os.path.isdir(os.path.join(home_directory, f))]
print(files_dir)
# Out:
# ['.anaconda', '.aws', '.cache', '.cdk', '.conda', '.config', '.docker', '.dvdcss', '.ipynb_checkpoints', '.ipython', '.jupyter', '.keras', '.local', '.MakeMKV', '.matplotlib', '.npm', '.nvm', '.pyenv', '.pylint.d', '.QtWebEngineProcess', '.ssh', '.VirtualBox', '.vscode', '.vscode-server', '3D Objects', 'Anaconda Work Space', 'AnacondaProjects', 'AppData', 'Application Data', 'aws', 'Contacts', 'Cookies', 'Desktop', 'dev', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'getting-started', 'Google ドライブ', 'intro-aws', 'Links', 'Local Settings', 'MicrosoftEdgeBackups', 'Music', 'My Documents', 'NetHood', 'nltk_data', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'sync_folder_for_priceless', 'Templates', 'test_document', 'thumb_tmp', 'Videos', 'VirtualBox VMs', 'スタート メニュー']

# %%
def dfs(dir):
    if os.path.isfile(dir):
        print(dir)
        read_binary(dir)
        print('\n')
    else:
        dir_list = os.listdir(dir)
        next_dir_list = [os.path.join(dir, f) for f in dir_list]
        for next_dir in next_dir_list:
            dfs(next_dir)

def main():
    init_dir = '/mnt/c/Users/veyro/Documents/mirai_emu'
    os.chdir(init_dir)
    dir_list = os.listdir(path='.')
    next_dir_list = [os.path.join(init_dir, f) for f in dir_list]
    for dir in next_dir_list:
        dfs(dir)
        
def read_binary(file):
    with open(file) as f:
        data = f.read()
        print(data)

# %%
main()
# Out:
# /mnt/c/Users/veyro/Documents/mirai_emu/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# {
#  "cells": [],
#  "metadata": {},
#  "nbformat": 4,
#  "nbformat_minor": 5
# }
#
#
#
# /mnt/c/Users/veyro/Documents/mirai_emu/downloader.py
#
#
#
# /mnt/c/Users/veyro/Documents/mirai_emu/mirai_emu.py
# '''
# 感染
#     MiraiバイナリをTFTP経由でダウンロード
#     自身をメモリにロード、自身を削除
#     C&Cサーバに接続し攻撃司令を待つ
# 感染後
#     Killerプロセス (感染ホストのバイナリを探索し、競合のマルウェアを削除)
#     22 (ssh),23 (telnet),80(http)ポートで動作しているサービスをすべて終了させ、それらを自身が参照
#     SYN-scanをIPv4アドレス空間からランダムに行い、重み付けした辞書攻撃を行う
#     攻撃に成功するとScan Receiverに認証情報を通知
#
# コーディング内容
# ・コードをTFTP経由でダウンロード
# ・疑似C&Cサーバに接続
# ・他のバイナリを探索
# ・他の機器 (IPアドレスは特定の機器に固定)に辞書攻撃
# '''
#
#
# /mnt/c/Users/veyro/Documents/mirai_emu/Untitled.ipynb
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "id": "b3a395aa",
#    "metadata": {},
#    "outputs": [],
#    "source": [
#     "import os"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 18,
# ...
